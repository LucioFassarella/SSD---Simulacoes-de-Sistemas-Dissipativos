# %% [markdown]
# <a href="https://colab.research.google.com/github/LucioFassarella/SSD---Simulacoes-de-Sistemas-Dissipativos/blob/main/SQSD_Modelo_qubit_amplitude_amortecida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color="red"><b>Simulação Quântica de Sistemas Dissipativos</b></font>
#
# <div align="center"><font color="magenta"><b>Qubit com amortecimento de AMPLITUDE</b></font></div>
# <!--
# <center><img align = "center" src="https://drive.google.com/uc?export=view&id=1usXrPscUXzfQF5wNtkvuVGARuuhcgyw-" alt="grafo" width="500"></center>
#
# <center>"You never understand things. You just get used to them." (John von Neumann)</center>
# -->
#
# ---
# **Referências**
#
# *   Daniel A. Lidar: *Lecture Notes on the Theory of Open Quantum Systems*. URL:
# [https://arxiv.org/abs/1902.00967](https://arxiv.org/abs/1902.00967).
#     *   (Lindbladian -> Kraus Operators: pp.47-48)
# *   Pirandola, Stefano *et al.*: *Minimal qudit code for a qubit in the phase-damping channel*. Physical Review A 77, 032309 (2008).
#
# *   Kline, S.J.: *Amplitude Damping vs Phase Damping in Quantum Computing: Key Differences and Impacts on Qubit Fidelity*. URL: [https://techiny.com/quantum-computing/amplitude-damping-vs-phase-damping](https://techiny.com/quantum-computing/amplitude-damping-vs-phase-damping).
#
# *   Bohrium: *Amplitude Damping and Phase Damping Channels*. URL: [https://www.bohrium.com/en/sciencepedia/feynman/quantum_information_quantum_computation-amplitude_da
#
# Qiskit
# *   [Método qiskit.quantum_info.Choi](https://quantum.cloud.ibm.com/docs/en/api/qiskit/qiskit.quantum_info.Choi)

# %% [markdown]
# **Espaço de Hilbert e equação de Lindblad**:
# $$
# \mathcal{H} = \mathcal{Q}_1
# $$
# $$
# \frac{d}{dt}\rho =\gamma\left(\sigma^+\rho \sigma^- - \frac{1}{2}\{\sigma^-\sigma^+,\rho\}\right),
# $$
# onde
# $$
# \sigma^+ := \vert0\rangle\langle 1 \vert,\ \sigma^-  :=\vert 1\rangle\langle 0 \vert.
# $$
# **Hamiltoniano e operador de Lindblad**:
# $$
# H =  \omega Z
# $$
# $$
# \begin{split}
# L_1 &:= \sigma^+,\\
# L_0 &:= - \frac{\gamma}{2} L_1^\dagger L_1 - i\omega Z = - \frac{\gamma}{2}\vert 1\rangle\langle 1 \vert - i\omega Z.
# \end{split}
# $$
# Operadores de Kraus infinitezimais com operador residual $R$:
# $$
# \begin{split}
# K_0 &= I -\left(\frac{\gamma}{2}\vert 1\rangle\langle 1 \vert + i\omega Z\right) dt + Rdt^2,\\
# K_1 &= \sqrt{\gamma dt}\sigma^+.
# \end{split}
# $$
# Equação residual:
# $$
# 	\begin{split}
# 		\frac{\gamma^2}{4}\vert 1\rangle\langle 1 \vert + \omega^2I + R + R^\dagger - \frac{\gamma}{2}( \vert 1\rangle\langle 1 \vert R + R^\dagger \vert 1\rangle\langle 1 \vert - i\omega ZR^\dagger + i\omega R Z )dt + R^\dagger R dt^2 = 0.
# 	\end{split}
# $$

# %% [markdown]
# Com o ansatz
# $$
# R = a \vert 0\rangle\langle 0 \vert + b \vert 1\rangle\langle 1 \vert\ \ (a,b \in \mathbb{R})
# $$
# a equação residual é reduzida um par de equações quadráticas para $a$ e $b$, cujas soluções obtemos explicitamente:
# $$
# \frac{\gamma^2}{4}\vert 1\rangle\langle 1 \vert + \omega^2 \vert 0\rangle\langle 0 \vert + \omega^2\vert 1\rangle\langle 1 \vert + 2a \vert 0\rangle\langle 0 \vert + 2b\vert 1\rangle\langle 1 \vert - \gamma b dt \vert 1\rangle\langle 1 \vert + dt^2a^2\vert 0\rangle\langle 0 \vert + dt^2b^2\vert 1\rangle\langle 1 \vert = 0
# $$
# ...
# $$
# \iff \left(\omega^2  + 2a + dt^2a^2 \right) \vert 0\rangle\langle 0 \vert +
# \left(\frac{\gamma^2}{4} + \omega^2 + 2b - \gamma dt b + dt^2b^2\right)\vert 1\rangle\langle 1 \vert= 0
# $$
# ...
# $$
# \iff \left\lbrace
# \begin{array}{l}
# \omega^2  + 2a + dt^2a^2 = 0 \\
# \frac{\gamma^2}{4} + \omega^2 + (2 - \gamma dt) b + dt^2b^2 = 0
# \end{array}
# \right.
# $$
# Soluções:
# $$
# a = - \frac{1 - \sqrt{1- \omega^2dt^2}}{dt^2} = - \frac{1}{2}\omega^2 + O(dt^2)
# $$
# e
# $$
# b  = - \frac{1 - \gamma dt/2 - \sqrt{1- \gamma dt - \omega^2 dt^2}}{dt^2} = - \left( \frac{\omega^2}{2} + \frac{\gamma^2}{8} \right) + O(dt^2).
# $$

# %% [markdown]
# **Isometria de Stinespring**
#
# $$
# \begin{split}
# \mathcal{V} &= \mathrm{spam}\left\{K_0\vert 0\rangle\otimes\vert0\rangle + K_1\vert 0\rangle\otimes\vert1\rangle,\ %
# K_0\vert 1\rangle\otimes\vert0\rangle + K_1\vert 1\rangle\otimes\vert1\rangle \right\}\\
# &=\mathrm{spam}\left\{\kappa_{0}\vert 0\rangle\otimes\vert0\rangle,\ %
# \kappa_{1} \vert 1\rangle\otimes\vert 0\rangle + \kappa_{2}\vert 0\rangle\otimes\vert 1\rangle \right\},
# \end{split}
# $$
# onde
# $$
# \begin{split}
# \kappa_{0} &:= 1 + adt^2 - i\omega dt\\
# \kappa_{1} &:= 1 - \gamma dt/2  + bdt^2 + i\omega dt\\
# \kappa_{2} &:= \sqrt{\gamma dt}.
# \end{split}
# $$
#
# **Unitário de Stinespring**
#
# Base ortonormal de $\mathcal{V}$:
# $$
# \begin{split}
# \vert\phi_{00}\rangle &:= \kappa_{0}\vert 0\rangle\otimes\vert 0\rangle \\
# \vert\phi_{01}\rangle &:= +\kappa_{1} \vert 1\rangle\otimes\vert 0\rangle + \kappa_{2}\vert 0\rangle\otimes\vert 1\rangle
# \end{split}
# $$
#
# Base ortonormal de $\mathcal{V}^\perp$:
# $$
# \begin{split}
# \vert\phi_{10}\rangle &:=- \kappa_{2} \vert 1\rangle\otimes\vert 0\rangle + \kappa_{1}\vert 0\rangle\otimes\vert 1\rangle\\
# \vert\phi_{11}\rangle &:= \kappa_{1}\vert 0\rangle\otimes\vert 1\rangle
# \end{split}
# $$
# Unitário de Stinespring:
# $$
# \begin{split}
# W \ \ \vert j\rangle\otimes\vert k\rangle \mapsto \vert \phi_{jk}\rangle,\ \ j,=0,1.
# \end{split}
# $$

# %% [markdown]
# ## QISKIT: Carregamento

# %%
# !pip install qiskit -U
# !pip install qiskit_aer -U
# !pip install qiskit-ibm-runtime -U

# !pip install matplotlib
# !pip install pylatexenc

import qiskit
qiskit.__version__
# Out:
# Collecting qiskit
#   Downloading qiskit-2.5.0-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: numpy<3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from qiskit) (2.0.2)
# Requirement already satisfied: scipy>=1.14 in /usr/local/lib/python3.12/dist-packages (from qiskit) (1.16.3)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Downloading rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.3.8)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Downloading stevedore-5.9.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit) (4.16.0)
# Downloading qiskit-2.5.0-cp310-abi3-manylinux_2_28_x86_64.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 35.8 MB/s eta 0:00:00
# Downloading rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 30.2 MB/s eta 0:00:00
# Downloading stevedore-5.9.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: stevedore, rustworkx, qiskit
# Successfully installed qiskit-2.5.0 rustworkx-0.18.0 stevedore-5.9.0
# Collecting qiskit_aer
#   Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Requirement already satisfied: qiskit>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit_aer) (2.5.0)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.12/dist-packages (from qiskit_aer) (2.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit_aer) (1.16.3)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit_aer) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit_aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit_aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit_aer) (0.18.0)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit_aer) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit_aer) (5.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit_aer) (4.16.0)
# Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 105.5 MB/s eta 0:00:00
# Installing collected packages: qiskit_aer
# Successfully installed qiskit_aer-0.17.2
# Collecting qiskit-ibm-runtime
#   Downloading qiskit_ibm_runtime-0.48.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests>=2.32.4 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.32.4)
# Collecting requests-ntlm>=1.1.0 (from qiskit-ibm-runtime)
#   Downloading requests_ntlm-1.3.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.0.2)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (1.16.3)
# Requirement already satisfied: urllib3>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.9.0.post0)
# Collecting ibm-platform-services>=0.61.1 (from qiskit-ibm-runtime)
#   Downloading ibm_platform_services-0.76.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting ibm-quantum-schemas<1,>=0.9.20260612 (from qiskit-ibm-runtime)
#   Downloading ibm_quantum_schemas-0.9.20260612-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: pydantic>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.13.4)
# Requirement already satisfied: qiskit>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.5.0)
# Collecting pybase64>=1.4.0 (from qiskit-ibm-runtime)
#   Downloading pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (8.7 kB)
# Collecting samplomatic>=0.18.0 (from qiskit-ibm-runtime)
#   Downloading samplomatic-0.20.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting ibm_cloud_sdk_core<4.0.0,>=3.24.4 (from ibm-platform-services>=0.61.1->qiskit-ibm-runtime)
#   Downloading ibm_cloud_sdk_core-3.26.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->qiskit-ibm-runtime) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->qiskit-ibm-runtime) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->qiskit-ibm-runtime) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.9.0->qiskit-ibm-runtime) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.3.0->qiskit-ibm-runtime) (0.18.0)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.3.0->qiskit-ibm-runtime) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.3.0->qiskit-ibm-runtime) (5.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.4->qiskit-ibm-runtime) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.4->qiskit-ibm-runtime) (3.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.4->qiskit-ibm-runtime) (2026.6.17)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.12/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (49.0.0)
# Collecting pyspnego>=0.4.0 (from requests-ntlm>=1.1.0->qiskit-ibm-runtime)
#   Downloading pyspnego-0.12.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from samplomatic>=0.18.0->qiskit-ibm-runtime) (3.11.9)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.1.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.4->ibm-platform-services>=0.61.1->qiskit-ibm-runtime) (2.13.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (3.0)
# Downloading qiskit_ibm_runtime-0.48.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 29.1 MB/s eta 0:00:00
# Downloading ibm_platform_services-0.76.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.4/400.4 kB 31.5 MB/s eta 0:00:00
# Downloading ibm_quantum_schemas-0.9.20260612-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.3/111.3 kB 7.8 MB/s eta 0:00:00
# Downloading pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 3.7 MB/s eta 0:00:00
# Downloading requests_ntlm-1.3.0-py3-none-any.whl (6.6 kB)
# Downloading samplomatic-0.20.0-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.2/224.2 kB 19.5 MB/s eta 0:00:00
# Downloading ibm_cloud_sdk_core-3.26.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 kB 6.7 MB/s eta 0:00:00
# Downloading pyspnego-0.12.1-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 12.6 MB/s eta 0:00:00
# Installing collected packages: pybase64, ibm_cloud_sdk_core, samplomatic, pyspnego, ibm-platform-services, requests-ntlm, ibm-quantum-schemas, qiskit-ibm-runtime
# Successfully installed ibm-platform-services-0.76.0 ibm-quantum-schemas-0.9.20260612 ibm_cloud_sdk_core-3.26.0 pybase64-1.4.3 pyspnego-0.12.1 qiskit-ibm-runtime-0.48.0 requests-ntlm-1.3.0 samplomatic-0.20.0
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting pylatexenc
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=69da327bb1a65d972229d54565c32a64227ad045af94e9ecf35a93f872f2b62d
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: pylatexenc
# Successfully installed pylatexenc-2.10
# '2.5.0'

# %%
'''
from qiskit_ibm_runtime import QiskitRuntimeService

# Conecção com a IBM

token_privado = "" # <-- Inserir token privado na IBM
instance_do_projeto = "" # <-- Inserir instance do projeto

from qiskit_ibm_runtime import QiskitRuntimeService
service = QiskitRuntimeService(
    channel="ibm_cloud",
    token = token_privado,
    instance = instance_do_projeto
    )

## Save account to disk and save it as the default.
#QiskitRuntimeService.save_account(channel="ibm_cloud", token="<IBM Cloud API key>", instance="<IBM Cloud CRN>", name="account-name", set_as_default=True)

## Load the saved credentials
#service = QiskitRuntimeService(name="account-name")
'''
# Out:
# '\nfrom qiskit_ibm_runtime import QiskitRuntimeService\n\n# Conecção com a IBM\n\ntoken_privado = "" # <-- Inserir token privado na IBM\ninstance_do_projeto = "" # <-- Inserir instance do projeto\n\nfrom qiskit_ibm_runtime import QiskitRuntimeService\nservice = QiskitRuntimeService(\n    channel="ibm_cloud",\n    token = token_privado,\n    instance = instance_do_projeto\n    )\n\n## Save account to disk and save it as the default.\n#QiskitRuntimeService.save_account(channel="ibm_cloud", token="<IBM Cloud API key>", instance="<IBM Cloud CRN>", name="account-name", set_as_default=True)\n\n## Load the saved credentials\n#service = QiskitRuntimeService(name="account-name")\n'

# %%
# Qiskit: métodos básicos

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister

from qiskit import transpile

from qiskit.visualization import plot_histogram, array_to_latex, plot_state_city

# %% [markdown]
# # Modelagem

# %%
"PARÂMETROS DO SISTEMA e da SIMULAÇÃO"

import numpy as np

# Parâmetros do sistema

w = 1.2 # Hamiltoniano
print(f"Parâmetro do Hamiltoniano: w = {w}")

g = 1 # taxa de dissipação
print(f"Taxa de dissipação: g = {g}")

# Parâmetros da simulação

tempo = 1 # duração da simulação
print(f"Tempo de simulação: tempo = {tempo}")

num_steps = 10 # número de passos da simulação
print(f"Número de passos da simulação: num_steps = {num_steps}")

dt = tempo/num_steps # step_size = magnitude de ada passo da simulação
print(f"Magnitude dos passos da simulação: dt = {dt}")

r = - (1.-g*dt/2 - np.sqrt(1. - g*dt - w**2*dt**2))/dt**2
print(f"Parâmetro r = {r}")

k0 = 1. - g*dt/2 + r*dt**2
print(f"Parâmetro k0 = {k0}")

k1 = -w*dt
print(f"Parâmetro k1 = {k1}")

theta = 2*np.arctan(np.sqrt(g*dt/k0**2 + k1**2))
print(f"Parâmetro theta = {theta}")

zeta = np.arctan(k1/k0)
print(f"Parâmetro zeta = {zeta}")
# Out:
# Parâmetro do Hamiltoniano: w = 1.2
# Taxa de dissipação: g = 1
# Tempo de simulação: tempo = 1
# Número de passos da simulação: num_steps = 10
# Magnitude dos passos da simulação: dt = 0.1
# Parâmetro r = -0.8936771518512574
# Parâmetro k0 = 0.9410632284814874
# Parâmetro k1 = -0.12
# Parâmetro theta = 0.6854683991689765
# Parâmetro zeta = -0.1268308680377276

# %%
"CIRCUITO QUÂNTICO DA SIMULAÇÃO"

num_qubts = 1 + num_steps # número de qubits do circuito quântico

qbt_system = QuantumRegister(1)  # registro quântico do sistema
qbt_clock = [QuantumRegister(1) for step in range(num_steps)] # registros para evolução temporal

cbt_system = ClassicalRegister(1) # registro clássico do sistema
cbt_clock = [ClassicalRegister(1) for step in range(num_steps)] # registros para medição temporal

qcirc = QuantumCircuit(qbt_system, *qbt_clock, cbt_system, *cbt_clock) # circuito quântico da simulação

#qc_simulacao.draw()

"ESTADO INICIAL"

qcirc.x(qbt_system[0])

"HAMILTONIANO"

# Hamiltoniano
from qiskit.quantum_info import SparsePauliOp

Hamiltoniano = SparsePauliOp.from_sparse_list([("Z", [0], w)], num_qubits= num_qubts) # Hamiltoniano

"UNITÁRIO DE STINESPRING"

from qiskit.circuit.library import UGate

W0_gate = UGate(theta, -zeta, zeta)
CW0_gate = W0_gate.control(1, ctrl_state = "0")

W1_gate = UGate(theta, zeta + np.pi, -zeta)
CW1_gate = W0_gate.control(1, ctrl_state = "1")

for step in range(num_steps):
    qcirc.append(CW0_gate, [qbt_system[0], qbt_clock[step][0]])
    qcirc.append(CW1_gate, [qbt_system[0], qbt_clock[step][0]])
    qcirc.barrier()

qcirc.draw('mpl')

# %%
"EXPERIMENTOS"

# %%
from qiskit_aer.primitives import Estimator as AerEstimator

# Remoção de medidas no circuito para executar o AerEstimator
qcirc_expval = qcirc.remove_final_measurements(inplace=False)

# Inicialização do Estimator
estimator = AerEstimator()

# Execução dos experimentos
job = estimator.run(qcirc_expval, Hamiltoniano)
result = job.result()

# Extração do valor esperado do Hamiltoniano
expectation_value = result.values[0]

print(f"<H>: {expectation_value}")
# Out:
# <H>: -1.2
