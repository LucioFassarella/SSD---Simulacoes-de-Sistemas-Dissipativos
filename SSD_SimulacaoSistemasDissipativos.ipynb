# %% [markdown]
# <a href="https://colab.research.google.com/github/LucioFassarella/SSD---Simulacoes-de-Sistemas-Dissipativos/blob/main/SSD_SimulacaoSistemasDissipativos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color="red"><b>Simulação Computacional Quântica de Sistemas Dissipativos</b></font>
#
# <center><img align = "center" src="https://drive.google.com/uc?export=view&id=1usXrPscUXzfQF5wNtkvuVGARuuhcgyw-" alt="grafo" width="500"></center>
#
# <center>"You never understand things. You just get used to them." (John von Neumann)</center>
#
# ---
#
# **Sistemas Quânticos Abertos**
#
# *   [[Carmichael2002](https://fassarella.online/archivi/Carmichael2002)] H. J. Carmichael:  *Statistical Methods in Quantum Optics 1*. Springer-Verlag, 2002.
#
#
# **Simulações computacionais quânticas**
#
#
# *   Hirsh Kamakari *et al.*: *Digital Quantum Simulation of Open Quantum Systems Using Quantum Imaginary–Time Evolution*. PRX Quantum, v.3(1), p.010320 [10 pages], 2022. DOI: 10.1103/PRXQuantum.3.010320. URL: [https://journals.aps.org/prxquantum/abstract/10.1103/PRXQuantum.3.010320](https://journals.aps.org/prxquantum/abstract/10.1103/PRXQuantum.3.010320).
# *   Hirsh Kamakari: *Investigation of quantum computers for quantum
# simulation and machine learning*. PHD thesis, Caltech, 2024. URL: [https://thesis.caltech.edu/16428/01/PHDTHESIS.pdf](https://thesis.caltech.edu/16428/01/PHDTHESIS.pdf).
# *   Mario Motta *et al.*: *Determining eigenstates and thermal states on a quantum computer using quantum imaginary time evolution*. Nature Physics volume 16, p.205-210 (2020). DOI: 10.1038/s41567-019-0704-4. URL: [https://www.nature.com/articles/s41567-019-0704-4](https://www.nature.com/articles/s41567-019-0704-4).
#
#
#
# <font color="cyan">Lindbladian -> Krauss' operators</font>
# *   Daniel A. Lidar: Lecture Notes on the Theory of Open Quantum Systems
# [https://arxiv.org/abs/1902.00967](https://arxiv.org/abs/1902.00967).
#     *   (Lindbladian -> Kraus Operators: pp.47-48)
# *   Laurent Sanchez-Palencia: Lecture 6: Open quantum systems I: Kraus-Lindblad approach
# [https://atom-tweezers-io.org/wp-content/uploads/2025/10/pqi2025-lecture6-open_quantum_systems.pdf](https://atom-tweezers-io.org/wp-content/uploads/2025/10/pqi2025-lecture6-open_quantum_systems.pdf).
#     *   (Lindbladian <-> Kraus Operators: pp.11-14)
#     *   <font color="green">Essas notas apresentam uma derivação formal simples e direta da equação de Lindblad a partir de uma evolução infinitesimal estroboscópica definida por operadores de Kraus. **Problema interessante**: para dado um sistema quântico (fechado) com seu Hamiltoniano, determinar condições sobre uma família de operadores de Kraus que definam uma dinâmica dissipativa para esse sistema tal que o correspondente estado assintótico coincida com o estado fundamental do sistema fechado, ou ao estado de equilíbrio termodinâmico a temperatura finita! </font>
# *   Timothy F. Havel: Robust procedures for converting among Lindblad, Kraus and matrix representations of quantum dynamical semigroups
# https://pubs.aip.org/aip/jmp/article-abstract/44/2/534/379835/Robust-procedures-for-converting-among-Lindblad
# https://arxiv.org/abs/quant-ph/0201127
# *   Zixuan Hu, Rongxin Xia & Sabre Kais: A quantum algorithm for evolving open quantum dynamics on quantum computing devices
# https://www.nature.com/articles/s41598-020-60321-x
# *   H. Nakazato, Y. Hida, K. Yuasa, B. Militello, A. Napoli, A. Messina: Solution of the Lindblad Equation in the Kraus Representation
#     *   https://journals.aps.org/pra/abstract/10.1103/PhysRevA.74.062113
# https://arxiv.org/abs/quant-ph/0606193
# *   Teoria da Informação Quântica: https://www.uio.no/studier/emner/matnat/math/MAT4430/v24/lecture14.pdf
#
# *   Stackexchange:
#     *   <font size="-2">https://physics.stackexchange.com/questions/751706/relating-the-lindbladian-to-kraus-operator-why-do-we-assume-the-specific-kraus</font>
#     *   <font size="-2">https://quantumcomputing.stackexchange.com/questions/25917/what-are-the-possible-kraus-operators-of-the-identity-channel/25965</font>
#     *   <font size="-2">https://quantumcomputing.stackexchange.com/questions/5811/what-is-the-stinespring-dilation</font>
#
# **Pessoas**
#
# *   [http://fernandobrandao.org/](http://fernandobrandao.org/)
# *   Preskill's Quantum Computation:
#     *   [https://preskill.caltech.edu/ph219/ph219_2026.html](https://preskill.caltech.edu/ph219/ph219_2026.html).
#     *   [https://www.preskill.caltech.edu/ph219/index.html#lecture](https://www.preskill.caltech.edu/ph219/index.html#lecture).
#
# ***
#
# <font color="red">**Tópicos**</font>
#
# *   <font color="blue">Lindbladiano de oscilador harmônico quântico amortecido: Carmichael2002, p.16</font>
# *   <font color = "blue">Lindbladiano de sistema de dois níveis em banho térmico: Carmichael2002, p.34.</font>
#     *   <font color="green">Kamakari2022 descreve a Trotterização da evolução temporal para equações de Lindblad.

# %% [markdown]
# ## QISKIT: Carregamento

# %%
# !pip install qiskit -U
# !pip install qiskit_aer -U
# !pip install qiskit-ibm-runtime -U

# !pip install matplotlib
# !pip install pylatexenc

import qiskit
qiskit.__version__
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 54.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 45.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 39.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 71.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.8/386.8 kB 24.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.5/102.5 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.0/218.0 kB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 9.9 MB/s eta 0:00:00
# ...

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

# Conecção com a IBM

token_privado = "7zAryvcpz2cTOgAbliiOL_A4qMyxg5Vq3nuHiBs1VENt" # <-- Inserir token privado na IBM
instance_do_projeto = "crn:v1:bluemix:public:quantum-computing:us-east:a/8e99d0dd96d44fd08e92d06df59c1d0a:8c991a39-9205-4233-9c72-dda37b057ae6::" # <-- Inserir instance do projeto

from qiskit_ibm_runtime import QiskitRuntimeService
service = QiskitRuntimeService(
    channel="ibm_cloud",
    token = token_privado,
    instance = instance_do_projeto
    )

## Save account to disk and save it as the default.
#QiskitRuntimeService.save_account(channel="ibm_cloud", token="<IBM Cloud API key>", instance="<IBM Cloud CRN>", name="account-name", set_as_default=True)

## Load the saved credentials
#service = QiskitRuntimeService(name="account-name")
# Out:
# qiskit_runtime_service._discover_account:WARNING:2026-05-25 19:04:44,119: Loading account with the given token. A saved account will not be used.

# %%
# Qiskit: métodos básicos

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister

from qiskit import transpile

from qiskit.visualization import plot_histogram, array_to_latex, plot_state_city
